# %% [markdown]
# # Model 1 - Evaluation 1
#
# [Model 1](readme.md) is a simple Bayesian regression model to predict word reading at end given age, receptive vocabulary, letter-sound knowledge, phonetic spelling, nonverbal ability, and word reading at start.
#
# The model is defined in [model.py](model.py).
#
# Here, we evaluate the model using observed variables from data set 1 with time 1 as the baseline and time 4 as the outcome.

# %% [markdown]
# ## Preliminaries

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import platform
import sys
import pymc as pm
import pytensor
import pytensor.tensor as pt
import model as m
from model import ModelSpecification

pd.options.mode.copy_on_write = True

environment = {
    "platform": platform.platform(),
    "python": sys.version,
    "pymc": pm.__version__,
    "pytensor": pytensor.__version__,
    "numpy": np.__version__,
    "arviz": az.__version__,
}

print("Environment:")
for key, value in environment.items():
    print(f"  {key}: {value}")
# Out:
# Environment:
#   platform: macOS-15.6.1-arm64-arm-64bit-Mach-O
#   python: 3.13.7 (v3.13.7:bcee1c32211, Aug 14 2025, 19:10:51) [Clang 16.0.0 (clang-1600.0.26.6)]
#   pymc: 5.25.1
#   pytensor: 2.31.7
#   numpy: 2.3.3
#   arviz: 0.22.0

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv(
    "../../../../../data/reading-language-intervention-trial/rli-trial-data.csv"
).convert_dtypes()
df = df[df["included"] == 1]

# %% [markdown]
# ## Evaluate model

# %% [markdown]
# ### Build model

# %%
spec = ModelSpecification(
    age=df["age_t1"].to_numpy(),
    nv_start=df["block_design_raw_t1"].to_numpy(),
    rv_start=df["recep_vocab_t1"].to_numpy(),
    ls_start=df["letter_sound_t1"].to_numpy(),
    sp_start=df["phon_spell_t1"].to_numpy(),
    wr_start=df["word_reading_t1"].to_numpy(),
    wr_end=df["word_reading_t4"].to_numpy(),
)

model_def = m.build_model(spec)

model = model_def.model

# %% [markdown]
# ### Model graph

# %%
pm.model_to_graphviz(model)

# %% [markdown]
# ### Run simulation

# %%
CHAINS = 8
CORES = 8
RANDOM_SEED = 202509
rng = np.random.default_rng(RANDOM_SEED)

with model:
    trace = pm.sample(
        draws=4000,
        tune=4000,
        chains=CHAINS,
        cores=CORES,
        target_accept=0.95,
        random_seed=RANDOM_SEED,
        return_inferencedata=True,
    )
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (8 chains in 8 jobs)
# NUTS: [alpha, beta_age, beta_nv, beta_rv, beta_ls, beta_sp, beta_wr, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 8 chains for 4_000 tune and 4_000 draw iterations (32_000 + 32_000 draws total) took 9 seconds.

# %%
with model:
    pm.compute_log_likelihood(trace)

    # Generate replicated outcomes end_obs from the posterior
    post_pred = pm.sample_posterior_predictive(
        trace.posterior,
        var_names=["end_obs"],
        random_seed=RANDOM_SEED,
        return_inferencedata=True,
    )

    # Prior predictive for prior checks
    prior_pred = pm.sample_prior_predictive(
        samples=1000,
        random_seed=RANDOM_SEED,
        return_inferencedata=True,
    )

    trace.extend(post_pred)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling: [end_obs]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling: [alpha, beta_age, beta_ls, beta_nv, beta_rv, beta_sp, beta_wr, end_obs, sigma]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Summary statistics
#
# #### Summary statistics (HDI probability = 95%)

# %%
summary = az.summary(
    trace,
    var_names=[
        "alpha",
        "beta_age",
        "beta_nv",
        "beta_rv",
        "beta_ls",
        "beta_sp",
        "beta_wr",
        "sigma",
    ],
    round_to=3,
    hdi_prob=0.95,
)
summary
# Out:
#             mean     sd  hdi_2.5%  hdi_97.5%  mcse_mean  mcse_sd   ess_bulk  \
# alpha     11.869  2.541     6.846     16.362      0.024    0.025  13360.872
# beta_age  -0.290  0.146    -0.591     -0.013      0.001    0.001  21526.485
# beta_nv    0.129  0.368    -0.616      0.840      0.003    0.003  22430.184
# beta_rv    0.460  0.225     0.045      0.920      0.002    0.002  16569.036
# beta_ls    0.689  0.306     0.109      1.307      0.002    0.003  17223.703
# beta_sp   -0.174  0.152    -0.478      0.128      0.001    0.001  15511.667
# beta_wr    1.185  0.264     0.683      1.726      0.002    0.002  16696.826
# sigma      7.638  1.407     5.110     10.419      0.013    0.011  11960.174
#
#            ess_tail  r_hat
# alpha     12477.535  1.001
# beta_age  16869.611  1.000
# beta_nv   17509.006  1.000
# beta_rv   14305.347  1.000
# beta_ls   13781.044  1.000
# beta_sp   15391.515  1.000
# beta_wr   14469.316  1.000
# sigma     15589.591  1.001

# %% [markdown]
# #### Summary statistics (HDI probability = 90%)

# %%
summary_90 = az.summary(
    trace,
    var_names=[
        "alpha",
        "beta_age",
        "beta_nv",
        "beta_rv",
        "beta_ls",
        "beta_sp",
        "beta_wr",
        "sigma",
    ],
    round_to=3,
    hdi_prob=0.9,
)
summary_90
# Out:
#             mean     sd  hdi_5%  hdi_95%  mcse_mean  mcse_sd   ess_bulk  \
# alpha     11.869  2.541   7.996   15.753      0.024    0.025  13360.872
# beta_age  -0.290  0.146  -0.519   -0.055      0.001    0.001  21526.485
# beta_nv    0.129  0.368  -0.465    0.715      0.003    0.003  22430.184
# beta_rv    0.460  0.225   0.108    0.827      0.002    0.002  16569.036
# beta_ls    0.689  0.306   0.191    1.163      0.002    0.003  17223.703
# beta_sp   -0.174  0.152  -0.422    0.067      0.001    0.001  15511.667
# beta_wr    1.185  0.264   0.763    1.611      0.002    0.002  16696.826
# sigma      7.638  1.407   5.412    9.821      0.013    0.011  11960.174
#
#            ess_tail  r_hat
# alpha     12477.535  1.001
# beta_age  16869.611  1.000
# beta_nv   17509.006  1.000
# beta_rv   14305.347  1.000
# beta_ls   13781.044  1.000
# beta_sp   15391.515  1.000
# beta_wr   14469.316  1.000
# sigma     15589.591  1.001

# %% [markdown]
# ### Trace plots

# %%
az.plot_trace(
    trace,
    var_names=[
        "alpha",
        "beta_age",
        "beta_nv",
        "beta_rv",
        "beta_ls",
        "beta_sp",
        "beta_wr",
        "sigma",
    ],
)
# Out:
# array([[<Axes: title={'center': 'alpha'}>,
#         <Axes: title={'center': 'alpha'}>],
#        [<Axes: title={'center': 'beta_age'}>,
#         <Axes: title={'center': 'beta_age'}>],
#        [<Axes: title={'center': 'beta_nv'}>,
#         <Axes: title={'center': 'beta_nv'}>],
#        [<Axes: title={'center': 'beta_rv'}>,
#         <Axes: title={'center': 'beta_rv'}>],
#        [<Axes: title={'center': 'beta_ls'}>,
#         <Axes: title={'center': 'beta_ls'}>],
#        [<Axes: title={'center': 'beta_sp'}>,
#         <Axes: title={'center': 'beta_sp'}>],
#        [<Axes: title={'center': 'beta_wr'}>,
#         <Axes: title={'center': 'beta_wr'}>],
#        [<Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'sigma'}>]], dtype=object)

# %% [markdown]
# ### Autocorrelation plots

# %%
az.plot_autocorr(trace, combined=True)
# Out:
# array([[<Axes: title={'center': 'alpha'}>,
#         <Axes: title={'center': 'beta_age'}>,
#         <Axes: title={'center': 'beta_nv'}>,
#         <Axes: title={'center': 'beta_rv'}>],
#        [<Axes: title={'center': 'beta_ls'}>,
#         <Axes: title={'center': 'beta_sp'}>,
#         <Axes: title={'center': 'beta_wr'}>,
#         <Axes: title={'center': 'sigma'}>]], dtype=object)

# %% [markdown]
# ## Forest plot
#
# The forest plot presents summaries of the posterior for each parameter. Points are the posterior means. The bars show the highest density interval. Thicker bars, if shown, are 50% HDI.

# %%
az.plot_forest(
    trace,
    var_names=[
        "alpha",
        "beta_age",
        "beta_nv",
        "beta_rv",
        "beta_ls",
        "beta_sp",
        "beta_wr",
        "sigma",
    ],
    hdi_prob=0.95,
)
# Out:
# array([<Axes: title={'center': '95.0% HDI'}>], dtype=object)

# %% [markdown]
# ### Rank plots
#
# Rank plots should be roughly flat; strong patterns hint at divergences or funnel geometry.

# %%
az.plot_rank(
    trace,
    var_names=[
        "alpha",
        "beta_age",
        "beta_nv",
        "beta_rv",
        "beta_ls",
        "beta_sp",
        "beta_wr",
        "sigma",
    ],
)
# Out:
# array([[<Axes: title={'center': 'alpha'}, xlabel='Rank (all chains)', ylabel='Chain'>,
#         <Axes: title={'center': 'beta_age'}, xlabel='Rank (all chains)', ylabel='Chain'>,
#         <Axes: title={'center': 'beta_nv'}, xlabel='Rank (all chains)', ylabel='Chain'>,
#         <Axes: title={'center': 'beta_rv'}, xlabel='Rank (all chains)', ylabel='Chain'>],
#        [<Axes: title={'center': 'beta_ls'}, xlabel='Rank (all chains)', ylabel='Chain'>,
#         <Axes: title={'center': 'beta_sp'}, xlabel='Rank (all chains)', ylabel='Chain'>,
#         <Axes: title={'center': 'beta_wr'}, xlabel='Rank (all chains)', ylabel='Chain'>,
#         <Axes: title={'center': 'sigma'}, xlabel='Rank (all chains)', ylabel='Chain'>]],
#       dtype=object)

# %% [markdown]
# ### Energy plot
#
# Energy plot / E-BFMI: very low values suggest poor exploration; reparameterise or standardise.

# %%
az.plot_energy(trace)
# Out:
# <Axes: >

# %% [markdown]
# ### Posterior predictive checks

# %%
az.plot_ppc(post_pred, data_pairs={"end_obs": "end_obs"})
# Out:
# <Axes: xlabel='end_obs'>
# /Users/frankbuckley/dev/dseinternational/development-models/.venv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Prior predictive checks

# %%
az.plot_ppc(prior_pred, group="prior", data_pairs={"end_obs": "end_obs"})
# Out:
# <Axes: xlabel='end_obs'>
